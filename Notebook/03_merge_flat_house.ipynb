# %%
import pandas as pd
import numpy as np

# %%
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

# %%
flats = pd.read_csv("../data/flats_cleaned.csv")
houses = pd.read_csv("../data/house_cleaned.csv")

# %%
df = pd.concat([flats,houses],ignore_index=True)

# %%
#Randomaly shuffle all the data
df = df.sample(df.shape[0],ignore_index=True)

# %%
df.head()
# Out:
#                                      property_name property_type  \
# 0                  3 BHK Flat in Sector 86 Gurgaon          flat
# 1                  2 BHK Flat in Sector 85 Gurgaon          flat
# 2  4 Bedroom House for sale in Sushant Lok Phase 3         house
# 3                  1 BHK Flat in Sector 95 Gurgaon          flat
# 4    5 Bedroom House for sale in Sector 66 Gurgaon         house
#
#                  society  price  price_per_sqft     area  \
# 0       dlf the skycourt   1.58          8190.0   1929.0
# 1            ss the leaf   1.20          7317.0   1640.0
# 2  ansals florence villa   6.00         22222.0   2700.0
# 3             rof ananda   0.21            61.0  34426.0
# 4     emaar mgf marbella    NaN             NaN      NaN
#
#                                         areaWithType  bedRoom  bathroom  \
# 0  Super Built up area 1929(179.21 sq.m.)Built Up...        3         3
# 1             Super Built up area 1640(152.36 sq.m.)        2         2
# 2                        Plot area 300(250.84 sq.m.)        4         5
# 3                 Carpet area: 34401 (3195.96 sq.m.)        1         1
# 4                        Plot area 500(418.06 sq.m.)        5         7
#
#   balcony                                 additionalRoom  \
# 0       1                                     pooja room
# 1       3                                  not available
# 2       2                        pooja room,servant room
# 3       1                                  not available
# 4      3+  pooja room,store room,study room,servant room
#
#                                           address  floorNum facing  \
# 0        101, Sector 86 Gurgaon, Gurgaon, Haryana      16.0  North
# 1             Sector 85 Gurgaon, Gurgaon, Haryana      12.0  South
# 2  B Block, Sushant Lok Phase 3, Gurgaon, Haryana       2.0    NaN
# 3             Sector 95 Gurgaon, Gurgaon, Haryana      13.0  North
# 4      Md-45, Sector 66 Gurgaon, Gurgaon, Haryana       2.0    NaN
#
#       agePossession                                    nearbyLocations  \
# 0   1 to 5 Year Old  ['Sapphire 83 Mall', 'NH-8, Imt Manesar', 'Rao...
# 1   1 to 5 Year Old  ['Sapphire 83 Mall', 'Dwarka Expressway', 'Cen...
# 2      10+ Year Old  ['Radhakrishna Shani Mandir', 'Sanatan Dharm M...
# 3   1 to 5 Year Old  ['Metro', 'Dwarka Expressway', 'Rajeev Chowk',...
# 4  5 to 10 Year Old  ['Sector 55-56 Rapid Metro Station', 'HUB 66',...
#
#                                          description  \
# 0  This beautiful 3 bhk flat in sector 86 gurgaon...
# 1  Its a beautiful 2 bhk apartment available for ...
# 2  30meter road verry good loction nery by market...
# 3  Ambitious, personable agent with 15 years of e...
# 4  Property is located in very posh area, park fa...
#
#                                       furnishDetails  \
# 0  ['3 Wardrobe', '5 Fan', '1 Exhaust Fan', '3 Ge...
# 1  ['5 Fan', '1 Exhaust Fan', '2 Geyser', '10 Lig...
# 2  ['1 Water Purifier', '9 Fan', '1 Exhaust Fan',...
# 3                                                NaN
# 4  ['16 Fan', '1 Exhaust Fan', '8 Geyser', '1 Sto...
#
#                                             features  \
# 0  ['Centrally Air Conditioned', 'Water purifier'...
# 1  ['Centrally Air Conditioned', 'Water purifier'...
# 2  ['Feng Shui / Vaastu Compliant', 'Park', 'Rain...
# 3  ['Security / Fire Alarm', 'Intercom Facility',...
# 4  ['Feng Shui / Vaastu Compliant', 'Private Gard...
#
#                                               rating
# 0  ['Green Area5 out of 5', 'Construction5 out of...
# 1  ['Green Area4.5 out of 5', 'Construction4.5 ou...
# 2  ['Environment4 out of 5', 'Lifestyle4 out of 5...
# 3  ['Environment4 out of 5', 'Lifestyle4.5 out of...
# 4  ['Environment3 out of 5', 'Lifestyle4 out of 5...

# %%
df.shape
# Out:
# (3961, 20)

# %%
df.to_csv('../data/gurgaon_properties.csv',index=False)
